# %% [markdown]
# <a href="https://colab.research.google.com/github/Clarice-Satiko-Aoto/b2b-analyis/blob/feat/vendasB2B_feat_eng_vendas_metas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bibliotecas

# %%
#importar bibliotecas
import pandas as pd

#warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Carregar arquivos necessarios

# %%
#carregar arquivo

# df tratado
df_vendas = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/tratado/tratado.csv',
                 parse_dates=['data'])
#de para
dfDePara = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/tratado/de_para.csv')

#Metas 2022 e 2023
df_metas = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/vendas/data/tratado/metas22-23.csv",
                       parse_dates=['data'])

# %% [markdown]
# # merge dos dataframes

# %%
#merge do df_metas e df_vendas
#O how='outer' garante que todas as datas presentes nos
#DataFrames de vendas e metas serão mantidas no resultado do merge.

df_historico = df_vendas.merge(df_metas, on=['data', 'gerente_id', 'categoria_id'], how='left')
df_historico.head()
# Out:
#    vendas_id       data      nfe  cliente_id  nf_desconto  valor_liquido  \
# 0          1 2021-02-16  SO43660         614        24.90            265
# 1       3020 2023-06-10  SO87451          50       398.45           5758
# 2        993 2021-06-24  SO46324         259        62.80           1014
# 3          7 2021-02-17  SO43665         347       112.95           1711
# 4       2443 2022-08-15  SO51151         318       545.55           8066
#
#    valor_venda  itens_venda_id  produto_id  item_quantidade  ...  \
# 0       240.10              13          43                1  ...
# 1      5359.55           46451          43                1  ...
# 2       951.20            7650          43                1  ...
# 3      1598.05              61          43                1  ...
# 4      7520.45           31879          43                1  ...
#
#    supervisor_id  gerente_id  categoria_id  produto_descricao tamanho  \
# 0              2           1             2            Paeonia       M
# 1              5           2             2            Paeonia       M
# 2              5           2             2            Paeonia       M
# 3              5           2             2            Paeonia       M
# 4              5           2             2            Paeonia       M
#
#   custoUnitario categoria_descricao meta_mensal  $_Meta_por_dia_util  \
# 0            75         Manga Curta         NaN                  NaN
# 1            75         Manga Curta    50769.23          2307.692273
# 2            75         Manga Curta         NaN                  NaN
# 3            75         Manga Curta         NaN                  NaN
# 4            75         Manga Curta    69669.00          3029.090000
#
#    meta_diaria_ind
# 0              NaN
# 1           384.62
# 2              NaN
# 3              NaN
# 4           504.85
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Checar o merge

# %%
#Checar as datas inicial e final
df_historico.data.min(), df_historico.data.max()
# Out:
# (Timestamp('2021-02-16 00:00:00'), Timestamp('2023-10-22 00:00:00'))

# %%
df_vendas[df_vendas.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [vendas_id, data, nfe, cliente_id, nf_desconto, valor_liquido, valor_venda, itens_venda_id, produto_id, item_quantidade, valor_unitario, valor_bruto, valor_desconto, geografia_id, cliente, cidade, estado, UF, Regiao, vendedor_id, supervisor_id, gerente_id, categoria_id, produto_descricao, tamanho, custoUnitario, categoria_descricao]
# Index: []
#
# [0 rows x 27 columns]

# %%
df_vendas.loc[df_vendas['data']=='2022-07-31']
# Out:
#        vendas_id       data      nfe  cliente_id  nf_desconto  valor_liquido  \
# 38597       2400 2022-07-31  SO51107         161         78.0            299
# 39918       2400 2022-07-31  SO51107         161         78.0            299
#
#        valor_venda  itens_venda_id  produto_id  item_quantidade  ...  UF  \
# 38597        221.0           30754          45                1  ...  RN
# 39918        221.0           30753          59                1  ...  RN
#
#        Regiao  vendedor_id  supervisor_id gerente_id categoria_id  \
# 38597       2            4              2          1            2
# 39918       2            4              2          1            2
#
#       produto_descricao tamanho  custoUnitario  categoria_descricao
# 38597           Paeonia       G             75          Manga Curta
# 39918          Folhagem      GG            130          Manga Curta
#
# [2 rows x 27 columns]

# %%
df_historico.loc[df_historico['data']=='2022-07-31']
# Out:
#        vendas_id       data      nfe  cliente_id  nf_desconto  valor_liquido  \
# 38597       2400 2022-07-31  SO51107         161         78.0            299
# 39918       2400 2022-07-31  SO51107         161         78.0            299
#
#        valor_venda  itens_venda_id  produto_id  item_quantidade  ...  \
# 38597        221.0           30754          45                1  ...
# 39918        221.0           30753          59                1  ...
#
#        supervisor_id  gerente_id  categoria_id  produto_descricao tamanho  \
# 38597              2           1             2            Paeonia       G
# 39918              2           1             2           Folhagem      GG
#
#       custoUnitario categoria_descricao meta_mensal  $_Meta_por_dia_util  \
# 38597            75         Manga Curta         NaN                  NaN
# 39918           130         Manga Curta         NaN                  NaN
#
#        meta_diaria_ind
# 38597              NaN
# 39918              NaN
#
# [2 rows x 30 columns]

# %% [markdown]
# ## Salvar o arquivo

# %%
#salvar o arquivo final
df_historico.to_csv("/content/drive/MyDrive/Colab Notebooks/vendas/data/tratado/historico.csv", index=False)
