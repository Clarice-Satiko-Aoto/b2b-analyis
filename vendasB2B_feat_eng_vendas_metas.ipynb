# %% [markdown]
# <a href="https://colab.research.google.com/github/Clarice-Satiko-Aoto/b2b-analyis/blob/main/vendasB2B_feat_eng_vendas_metas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bibliotecas

# %%
#importar bibliotecas
import pandas as pd

#warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Carregar arquivos necessarios

# %%
#carregar arquivo

# df tratado
df_vendas = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/tratado/tratado.csv',
                 parse_dates=['data'])
#de para
dfDePara = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vendas/data/tratado/de_para.csv')

#Metas 2022 e 2023
df_metas = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/vendas/data/tratado/metas22-23.csv",
                       parse_dates=['data'])

# %%
#merge do df_metas e df_vendas
#O how='outer' garante que todas as datas presentes nos
#DataFrames de vendas e metas serão mantidas no resultado do merge.

df_historico = df_metas.merge(df_vendas, on=['data', 'gerente_id', 'categoria_id'], how='outer')
df_historico.head()
# Out:
#         data  gerente_id  categoria_id  meta_mensal  $_Meta_por_dia_util  \
# 0 2022-01-03           1             1      22586.0              1075.52
# 1 2022-01-03           1             1      22586.0              1075.52
# 2 2022-01-03           1             1      22586.0              1075.52
# 3 2022-01-03           1             1      22586.0              1075.52
# 4 2022-01-03           1             1      22586.0              1075.52
#
#    meta_diaria_ind  vendas_id      nfe  cliente_id  nf_desconto  ...  cidade  \
# 0           179.25     1800.0  SO48769       298.0        432.9  ...  Manaus
# 1           179.25     1800.0  SO48769       298.0        432.9  ...  Manaus
# 2           179.25     1800.0  SO48769       298.0        432.9  ...  Manaus
# 3           179.25     1800.0  SO48769       298.0        432.9  ...  Manaus
# 4           179.25     1800.0  SO48769       298.0        432.9  ...  Manaus
#
# ...

# %%
#Checar as datas inicial e final
df_historico.data.min(), df_historico.data.max()
# Out:
# (Timestamp('2021-02-16 00:00:00'), Timestamp('2023-12-31 00:00:00'))

# %%
#salvar o arquivo final
df_historico.to_csv("/content/drive/MyDrive/Colab Notebooks/vendas/data/tratado/historico.csv", index=False)
